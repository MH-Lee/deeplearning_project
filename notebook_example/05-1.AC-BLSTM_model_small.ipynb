# %% [markdown]
# ## 01. package load

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive/mge511_preject/
# Out:
# /content/drive/My Drive/mge511_preject

# %%
import os
import sys
import json
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models.word2vec import Word2Vec
sys.path.append(os.pardir)
from models.ac_blstm_kr import ACBLSTMClassifier
from models.word_embedding import get_embedding_matrix

# %% [markdown]
# ### local gpu setting

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# ### Assing data path

# %%
DATA_IN_PATH = './assets/data/npy_data/2020-05-31/'
DATA_OUT_PATH = './model_save/cnn_model/'
# Data save label
TRAIN_INPUT_DATA = 'train_input.npy'
TEST_INPUT_DATA = 'test_input.npy'
DATA_CONFIGS = 'data_configs.json'
SEQ_CONFIGS = 'seq_configs_bt.json'

# Train label save file name
TRAIN_LABEL_DATA = 'train_label.npy'
TRAIN_LABEL_SMALL = 'train_label_small.npy'
TEST_LABEL_DATA = 'test_label.npy'
TEST_LABEL_SMALL = 'test_label_small.npy'

# %% [markdown]
# ### set cnn parameter

# %% [markdown]
# ## AC-LSTM train module parameter
#
# + parameter and default value
#
#     embedding_matrix=None (word2vec or doc2vec weight matrix)
#     vocab_size=None  (train vocab size)
#     pre_trained_mode=None ('d2v', 'w2v', 'pt_w2v')
#     num_filters=128
#     lstm_dimension=256
#     hidden_dimension=128
#     dropout_rate=0.5
#     batch_size = 512
#     num_epochs = 1000
#     valid_split = 0.2
#     optimizer = 'adam'  ('adam' or 'radam')
#     train_mode='rand ' ('rand', 'pt')
#
#
# + pt_w2v is pre-trained word2vec which is trained korean wikipedia doctumentation(document size : 420000)
# + embedding_matrix and pre_trained_mode cannot assign when train_mode is 'rand'
# + embedding_matrix and pre_trained_mode can assign when train_mode is 'pt'

# %%
from notebook_example.ac_blstm_train import ACBLSTMTrain

# %% [markdown]
# ## 02. Load  Data and make embedding matrix

# %% [markdown]
# + Load embedding data

# %%
w2v_model_name = './model_save/embedding_model/Word2vec1.model'
word_vectorizer = Word2Vec.load(w2v_model_name)

pre_trained_name = './model_save/embedding_model/trained_word2vec1.model'
pre_trained_w2v = Word2Vec.load(pre_trained_name)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %% [markdown]
# + Load data

# %%
train_X = np.load(open(DATA_IN_PATH + TRAIN_INPUT_DATA, 'rb'))
train_Y = np.load(open(DATA_IN_PATH + TRAIN_LABEL_SMALL, 'rb'))
test_X = np.load(open(DATA_IN_PATH + TEST_INPUT_DATA, 'rb'))
test_Y = np.load(open(DATA_IN_PATH + TEST_LABEL_SMALL, 'rb'))
train_YS = tf.one_hot(train_Y, 455)
test_YS = tf.one_hot(test_Y, 455)
data_configs = json.load(open(DATA_IN_PATH + DATA_CONFIGS, 'r'))
vocab_size = data_configs['vocab_size'] + 1
print("vocab_size : ", vocab_size)
word_index = data_configs['vocab']
# Out:
# vocab_size :  30079

# %% [markdown]
# ## 04. AC-BLSTM with w2v

# %% [markdown]
# ### optimizer adam

# %%
acblstm_train_w2v = ACBLSTMTrain(vocab_size=vocab_size,
                                 train_mode='pt',
                                 batch_size=512,
                                 output_dim=455,
                                 embedding_matrix=word_vectorizer,
                                 word_index=word_index,
                                 pre_trained_mode='w2v')
# Out:
# small_class
# output_dim :  455
# ./model_save/acblstm_model_small/
# word index size :  30079
# 27423 2655
# train_mode : pt, optimizer : adam, pre-trained_mode : w2v, model_name : AC-BLSTM_pt_adam_w2v

# %%
model, histroy = acblstm_train_w2v.train(train_X, train_YS)
# Out:
# {'vocab_size': 30079, 'embedding_size': 300, 'num_filters': 128, 'dropout_rate': 0.5, 'lstm_dimension': 256, 'hidden_dimension': 500, 'train_mode': 'pt', 'output_dimension': 455, 'model_name': 'AC-BLSTM_pt_adam_w2v', 'embedding_matrix': array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.05204903, -0.21638015, -0.21948703, ...,  0.14667457,
#         -0.02240289,  0.05068133],
#        [-0.00398654,  0.07112884, -0.51496243, ...,  0.07860778,
#         -0.33473143, -0.0859189 ],
#        ...,
#        [-0.60012555,  0.33054775, -0.45900419, ..., -0.22507869,
#          0.13599187, -0.08460996],
#        [ 0.48614532,  0.02564996, -0.16735327, ...,  0.38038063,
#          0.16799502, -0.66553634],
#        [ 0.79622883, -0.40894818,  0.2396446 , ..., -0.12865892,
#         -0.75648826,  0.38904482]])}
# ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v -- Folder already exists
#
# callback set
# Epoch 1/1000
# 34/34 [==============================] - ETA: 0s - loss: 6.0762 - accuracy: 0.0086 - f1_score: 3.1105e-04
# Epoch 00001: val_accuracy improved from -inf to 0.01344, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 6s 180ms/step - loss: 6.0762 - accuracy: 0.0086 - f1_score: 3.1105e-04 - val_loss: 6.0253 - val_accuracy: 0.0134 - val_f1_score: 3.9756e-04
# Epoch 2/1000
# 34/34 [==============================] - ETA: 0s - loss: 5.6814 - accuracy: 0.0213 - f1_score: 0.0014
# Epoch 00002: val_accuracy improved from 0.01344 to 0.02085, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 5.6814 - accuracy: 0.0213 - f1_score: 0.0014 - val_loss: 5.4956 - val_accuracy: 0.0209 - val_f1_score: 0.0017
# Epoch 3/1000
# 34/34 [==============================] - ETA: 0s - loss: 5.0888 - accuracy: 0.0498 - f1_score: 0.0075
# Epoch 00003: val_accuracy improved from 0.02085 to 0.06070, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 5.0888 - accuracy: 0.0498 - f1_score: 0.0075 - val_loss: 4.9489 - val_accuracy: 0.0607 - val_f1_score: 0.0091
# Epoch 4/1000
# 34/34 [==============================] - ETA: 0s - loss: 4.4230 - accuracy: 0.1147 - f1_score: 0.0233
# Epoch 00004: val_accuracy improved from 0.06070 to 0.12697, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 4.4230 - accuracy: 0.1147 - f1_score: 0.0233 - val_loss: 4.1810 - val_accuracy: 0.1270 - val_f1_score: 0.0285
# Epoch 5/1000
# 34/34 [==============================] - ETA: 0s - loss: 3.6693 - accuracy: 0.2000 - f1_score: 0.0699
# Epoch 00005: val_accuracy improved from 0.12697 to 0.19323, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 3.6693 - accuracy: 0.2000 - f1_score: 0.0699 - val_loss: 3.5398 - val_accuracy: 0.1932 - val_f1_score: 0.0695
# Epoch 6/1000
# 34/34 [==============================] - ETA: 0s - loss: 2.9312 - accuracy: 0.3164 - f1_score: 0.1612
# Epoch 00006: val_accuracy improved from 0.19323 to 0.27711, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 2.9312 - accuracy: 0.3164 - f1_score: 0.1612 - val_loss: 3.0188 - val_accuracy: 0.2771 - val_f1_score: 0.1346
# Epoch 7/1000
# 34/34 [==============================] - ETA: 0s - loss: 2.3422 - accuracy: 0.4346 - f1_score: 0.2721
# Epoch 00007: val_accuracy improved from 0.27711 to 0.36052, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 2.3422 - accuracy: 0.4346 - f1_score: 0.2721 - val_loss: 2.5273 - val_accuracy: 0.3605 - val_f1_score: 0.2087
# Epoch 8/1000
# 34/34 [==============================] - ETA: 0s - loss: 1.9011 - accuracy: 0.5302 - f1_score: 0.3871
# Epoch 00008: val_accuracy improved from 0.36052 to 0.42215, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 1.9011 - accuracy: 0.5302 - f1_score: 0.3871 - val_loss: 2.2329 - val_accuracy: 0.4222 - val_f1_score: 0.2726
# Epoch 9/1000
# 34/34 [==============================] - ETA: 0s - loss: 1.5038 - accuracy: 0.6350 - f1_score: 0.5190
# Epoch 00009: val_accuracy improved from 0.42215 to 0.46849, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 1.5038 - accuracy: 0.6350 - f1_score: 0.5190 - val_loss: 2.0035 - val_accuracy: 0.4685 - val_f1_score: 0.3268
# Epoch 10/1000
# 34/34 [==============================] - ETA: 0s - loss: 1.2187 - accuracy: 0.7160 - f1_score: 0.6212
# Epoch 00010: val_accuracy improved from 0.46849 to 0.51251, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 1.2187 - accuracy: 0.7160 - f1_score: 0.6212 - val_loss: 1.7947 - val_accuracy: 0.5125 - val_f1_score: 0.3918
# Epoch 11/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.9593 - accuracy: 0.7909 - f1_score: 0.7210
# Epoch 00011: val_accuracy improved from 0.51251 to 0.53197, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 0.9593 - accuracy: 0.7909 - f1_score: 0.7210 - val_loss: 1.7052 - val_accuracy: 0.5320 - val_f1_score: 0.4120
# Epoch 12/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.7760 - accuracy: 0.8368 - f1_score: 0.7919
# Epoch 00012: val_accuracy improved from 0.53197 to 0.58341, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 0.7760 - accuracy: 0.8368 - f1_score: 0.7919 - val_loss: 1.5746 - val_accuracy: 0.5834 - val_f1_score: 0.4615
# Epoch 13/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.8789 - f1_score: 0.8425
# Epoch 00013: val_accuracy improved from 0.58341 to 0.58526, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 0.6276 - accuracy: 0.8789 - f1_score: 0.8425 - val_loss: 1.5253 - val_accuracy: 0.5853 - val_f1_score: 0.4789
# Epoch 14/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.9216 - f1_score: 0.9005
# Epoch 00014: val_accuracy improved from 0.58526 to 0.60565, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 0.4876 - accuracy: 0.9216 - f1_score: 0.9005 - val_loss: 1.4423 - val_accuracy: 0.6057 - val_f1_score: 0.5049
# Epoch 15/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.3812 - accuracy: 0.9454 - f1_score: 0.9331
# Epoch 00015: val_accuracy improved from 0.60565 to 0.61956, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 0.3812 - accuracy: 0.9454 - f1_score: 0.9331 - val_loss: 1.3867 - val_accuracy: 0.6196 - val_f1_score: 0.5247
# Epoch 16/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.9601 - f1_score: 0.9492
# Epoch 00016: val_accuracy improved from 0.61956 to 0.62326, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 0.3069 - accuracy: 0.9601 - f1_score: 0.9492 - val_loss: 1.3725 - val_accuracy: 0.6233 - val_f1_score: 0.5209
# Epoch 17/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9760 - f1_score: 0.9689
# Epoch 00017: val_accuracy did not improve from 0.62326
# 34/34 [==============================] - 5s 134ms/step - loss: 0.2430 - accuracy: 0.9760 - f1_score: 0.9689 - val_loss: 1.3757 - val_accuracy: 0.6182 - val_f1_score: 0.5211
# Epoch 18/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.1964 - accuracy: 0.9832 - f1_score: 0.9800
# Epoch 00018: val_accuracy improved from 0.62326 to 0.63624, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 6s 163ms/step - loss: 0.1964 - accuracy: 0.9832 - f1_score: 0.9800 - val_loss: 1.3356 - val_accuracy: 0.6362 - val_f1_score: 0.5516
# Epoch 19/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9878 - f1_score: 0.9856
# Epoch 00019: val_accuracy improved from 0.63624 to 0.64411, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 0.1561 - accuracy: 0.9878 - f1_score: 0.9856 - val_loss: 1.3153 - val_accuracy: 0.6441 - val_f1_score: 0.5536
# Epoch 20/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9920 - f1_score: 0.9907
# Epoch 00020: val_accuracy improved from 0.64411 to 0.64597, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 0.1260 - accuracy: 0.9920 - f1_score: 0.9907 - val_loss: 1.2926 - val_accuracy: 0.6460 - val_f1_score: 0.5573
# Epoch 21/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.1037 - accuracy: 0.9942 - f1_score: 0.9929
# Epoch 00021: val_accuracy improved from 0.64597 to 0.65848, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 0.1037 - accuracy: 0.9942 - f1_score: 0.9929 - val_loss: 1.2856 - val_accuracy: 0.6585 - val_f1_score: 0.5634
# Epoch 22/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0870 - accuracy: 0.9948 - f1_score: 0.9931
# Epoch 00022: val_accuracy did not improve from 0.65848
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0870 - accuracy: 0.9948 - f1_score: 0.9931 - val_loss: 1.3375 - val_accuracy: 0.6483 - val_f1_score: 0.5516
# Epoch 23/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9970 - f1_score: 0.9961
# Epoch 00023: val_accuracy improved from 0.65848 to 0.67006, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 141ms/step - loss: 0.0733 - accuracy: 0.9970 - f1_score: 0.9961 - val_loss: 1.2738 - val_accuracy: 0.6701 - val_f1_score: 0.5791
# Epoch 24/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9963 - f1_score: 0.9947
# Epoch 00024: val_accuracy did not improve from 0.67006
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0639 - accuracy: 0.9963 - f1_score: 0.9947 - val_loss: 1.2920 - val_accuracy: 0.6645 - val_f1_score: 0.5761
# Epoch 25/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9969 - f1_score: 0.9959
# Epoch 00025: val_accuracy did not improve from 0.67006
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0544 - accuracy: 0.9969 - f1_score: 0.9959 - val_loss: 1.3117 - val_accuracy: 0.6668 - val_f1_score: 0.5756
# Epoch 26/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9972 - f1_score: 0.9962
# Epoch 00026: val_accuracy improved from 0.67006 to 0.67285, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 162ms/step - loss: 0.0478 - accuracy: 0.9972 - f1_score: 0.9962 - val_loss: 1.2941 - val_accuracy: 0.6728 - val_f1_score: 0.5849
# Epoch 27/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0439 - accuracy: 0.9977 - f1_score: 0.9970
# Epoch 00027: val_accuracy did not improve from 0.67285
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0439 - accuracy: 0.9977 - f1_score: 0.9970 - val_loss: 1.2984 - val_accuracy: 0.6705 - val_f1_score: 0.5825
# Epoch 28/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9981 - f1_score: 0.9974
# Epoch 00028: val_accuracy did not improve from 0.67285
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0377 - accuracy: 0.9981 - f1_score: 0.9974 - val_loss: 1.2975 - val_accuracy: 0.6719 - val_f1_score: 0.5873
# Epoch 29/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9976 - f1_score: 0.9962
# Epoch 00029: val_accuracy did not improve from 0.67285
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0365 - accuracy: 0.9976 - f1_score: 0.9962 - val_loss: 1.2888 - val_accuracy: 0.6724 - val_f1_score: 0.5826
# Epoch 30/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9977 - f1_score: 0.9968
# Epoch 00030: val_accuracy did not improve from 0.67285
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0339 - accuracy: 0.9977 - f1_score: 0.9968 - val_loss: 1.3102 - val_accuracy: 0.6659 - val_f1_score: 0.5805
# Epoch 31/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9979 - f1_score: 0.9969
# Epoch 00031: val_accuracy did not improve from 0.67285
# 34/34 [==============================] - 5s 132ms/step - loss: 0.0315 - accuracy: 0.9979 - f1_score: 0.9969 - val_loss: 1.2982 - val_accuracy: 0.6724 - val_f1_score: 0.5886
# Epoch 32/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9975 - f1_score: 0.9967
# Epoch 00032: val_accuracy improved from 0.67285 to 0.67424, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 6s 184ms/step - loss: 0.0278 - accuracy: 0.9975 - f1_score: 0.9967 - val_loss: 1.3041 - val_accuracy: 0.6742 - val_f1_score: 0.5875
# Epoch 33/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9977 - f1_score: 0.9968
# Epoch 00033: val_accuracy improved from 0.67424 to 0.67841, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 142ms/step - loss: 0.0246 - accuracy: 0.9977 - f1_score: 0.9968 - val_loss: 1.3011 - val_accuracy: 0.6784 - val_f1_score: 0.5932
# Epoch 34/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9979 - f1_score: 0.9970
# Epoch 00034: val_accuracy improved from 0.67841 to 0.68675, saving model to ./model_save/acblstm_model_small/AC-BLSTM_pt_adam_w2v/weights.h5
# 34/34 [==============================] - 5s 143ms/step - loss: 0.0229 - accuracy: 0.9979 - f1_score: 0.9970 - val_loss: 1.2855 - val_accuracy: 0.6867 - val_f1_score: 0.6011
# Epoch 35/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9977 - f1_score: 0.9966
# Epoch 00035: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0225 - accuracy: 0.9977 - f1_score: 0.9966 - val_loss: 1.3089 - val_accuracy: 0.6789 - val_f1_score: 0.5953
# Epoch 36/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9979 - f1_score: 0.9970
# Epoch 00036: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0200 - accuracy: 0.9979 - f1_score: 0.9970 - val_loss: 1.3118 - val_accuracy: 0.6803 - val_f1_score: 0.5993
# Epoch 37/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9979 - f1_score: 0.9970
# Epoch 00037: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0201 - accuracy: 0.9979 - f1_score: 0.9970 - val_loss: 1.3078 - val_accuracy: 0.6849 - val_f1_score: 0.6004
# Epoch 38/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9983 - f1_score: 0.9977
# Epoch 00038: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0181 - accuracy: 0.9983 - f1_score: 0.9977 - val_loss: 1.3190 - val_accuracy: 0.6803 - val_f1_score: 0.5954
# Epoch 39/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9978 - f1_score: 0.9968
# Epoch 00039: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0158 - accuracy: 0.9978 - f1_score: 0.9968 - val_loss: 1.3121 - val_accuracy: 0.6830 - val_f1_score: 0.5996
# Epoch 40/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9978 - f1_score: 0.9971
# Epoch 00040: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0165 - accuracy: 0.9978 - f1_score: 0.9971 - val_loss: 1.3202 - val_accuracy: 0.6770 - val_f1_score: 0.5997
# Epoch 41/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.9978 - f1_score: 0.9974
# Epoch 00041: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0170 - accuracy: 0.9978 - f1_score: 0.9974 - val_loss: 1.3101 - val_accuracy: 0.6821 - val_f1_score: 0.5953
# Epoch 42/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9983 - f1_score: 0.9973
# Epoch 00042: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0141 - accuracy: 0.9983 - f1_score: 0.9973 - val_loss: 1.3359 - val_accuracy: 0.6793 - val_f1_score: 0.5942
# Epoch 43/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9980 - f1_score: 0.9972
# Epoch 00043: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0133 - accuracy: 0.9980 - f1_score: 0.9972 - val_loss: 1.3388 - val_accuracy: 0.6830 - val_f1_score: 0.5939
# Epoch 44/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9985 - f1_score: 0.9977
# Epoch 00044: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0121 - accuracy: 0.9985 - f1_score: 0.9977 - val_loss: 1.3289 - val_accuracy: 0.6798 - val_f1_score: 0.5912
# Epoch 45/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0114 - accuracy: 0.9986 - f1_score: 0.9978
# Epoch 00045: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0114 - accuracy: 0.9986 - f1_score: 0.9978 - val_loss: 1.3282 - val_accuracy: 0.6821 - val_f1_score: 0.6017
# Epoch 46/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9983 - f1_score: 0.9975
# Epoch 00046: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0110 - accuracy: 0.9983 - f1_score: 0.9975 - val_loss: 1.3413 - val_accuracy: 0.6770 - val_f1_score: 0.5888
# Epoch 47/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9983 - f1_score: 0.9977
# Epoch 00047: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0123 - accuracy: 0.9983 - f1_score: 0.9977 - val_loss: 1.3503 - val_accuracy: 0.6742 - val_f1_score: 0.5896
# Epoch 48/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9983 - f1_score: 0.9973
# Epoch 00048: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0113 - accuracy: 0.9983 - f1_score: 0.9973 - val_loss: 1.3310 - val_accuracy: 0.6807 - val_f1_score: 0.5975
# Epoch 49/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9981 - f1_score: 0.9973
# Epoch 00049: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0102 - accuracy: 0.9981 - f1_score: 0.9973 - val_loss: 1.3433 - val_accuracy: 0.6789 - val_f1_score: 0.5938
# Epoch 50/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9983 - f1_score: 0.9975
# Epoch 00050: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0095 - accuracy: 0.9983 - f1_score: 0.9975 - val_loss: 1.3351 - val_accuracy: 0.6812 - val_f1_score: 0.5930
# Epoch 51/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9981 - f1_score: 0.9977
# Epoch 00051: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0125 - accuracy: 0.9981 - f1_score: 0.9977 - val_loss: 1.3745 - val_accuracy: 0.6719 - val_f1_score: 0.5911
# Epoch 52/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9985 - f1_score: 0.9979
# Epoch 00052: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0105 - accuracy: 0.9985 - f1_score: 0.9979 - val_loss: 1.3398 - val_accuracy: 0.6854 - val_f1_score: 0.6040
# Epoch 53/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0105 - accuracy: 0.9980 - f1_score: 0.9972
# Epoch 00053: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0105 - accuracy: 0.9980 - f1_score: 0.9972 - val_loss: 1.3655 - val_accuracy: 0.6742 - val_f1_score: 0.5914
# Epoch 54/1000
# 34/34 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9983 - f1_score: 0.9974
# Epoch 00054: val_accuracy did not improve from 0.68675
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0091 - accuracy: 0.9983 - f1_score: 0.9974 - val_loss: 1.3441 - val_accuracy: 0.6793 - val_f1_score: 0.5975

# %%
acblstm_train_w2v.train_plot(model, histroy)

# %%
acblstm_train_w2v.evaluation(model, test_X, test_YS)
# Out:
# 145/145 [==============================] - 2s 11ms/step - loss: 1.2634 - accuracy: 0.6808 - f1_score: 0.6134
